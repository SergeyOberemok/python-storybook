# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# %% [markdown]
# ### Polygon

# %%
points1 = np.array([[1, 1], [2, 2], [3, 1]])
points2 = np.array([[1, 2.5], [2, 1.5], [3, 2.5]])

polygon1 = Polygon(points1, facecolor='y', alpha=.5)
polygon2 = Polygon(points2, facecolor='b', alpha=.5)

_, axis = plt.subplots()

axis.add_patch(polygon1)
axis.add_patch(polygon2)
axis.set_xlim([0, 4])
axis.set_ylim([0, 3])

plt.show()

# %% [markdown]
# ### Excercise

# %%
xPoints = np.linspace(-2, 2, 101)
exp = -xPoints**2
points = np.vstack((xPoints, exp)).T

polygon = Polygon(points, facecolor='g', alpha=.5)

_, axis = plt.subplots()

axis.add_patch(polygon)
axis.set_xlim([-3, 3])
axis.set_ylim([-5, 1])

plt.show()
